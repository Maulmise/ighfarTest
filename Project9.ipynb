# %% [markdown]
# # Netflix Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/mighfar/data_analyst_projects/netflix_data.csv')
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df = df.drop_duplicates(keep='first')
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# ### 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
df[df.Title == 'House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#         year Release_Date Rating   Duration                     Type  \
# 2832  2018.0   2018-11-02  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
pd.to_datetime(df['Release_Date'], format="%B %d, %Y")
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7784   2020-10-19
# 7785   2019-03-02
# 7786   2020-09-25
# 7787   2020-10-31
# 7788   2020-03-01
# Name: Release_Date, Length: 7787, dtype: datetime64[ns]

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
from datetime import datetime as dt
# df.insert(6,'year',df['Release_Date'].dt.year)
df_bar = df.groupby('year').Show_Id.count()
df_bar
# Out:
# year
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0      11
# 2014.0      25
# 2015.0      88
# 2016.0     443
# 2017.0    1225
# 2018.0    1685
# 2019.0    2153
# 2020.0    2009
# 2021.0     117
# Name: Show_Id, dtype: int64

# %%
df_bar.index
# Out:
# Float64Index([2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0,
#               2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0],
#              dtype='float64', name='year')

# %% [raw]
# df_bar.values

# %%
df_bar.values
# Out:
# array([   2,    2,    1,   13,    3,   11,   25,   88,  443, 1225, 1685,
#        2153, 2009,  117])

# %%
df_bar.plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
sns.barplot(x=df_bar.index, y=df_bar.values, data=df_bar)
plt.xlabel('year')
plt.ylabel('numbers of movies')
plt.show()

# %% [markdown]
# ### 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
df2 = df.groupby('Category').Show_Id.count()

# %%
df['Category'] = df['Category'].astype('category')
sns.countplot(df['Category'])
plt.show()
# Out:
# /tmp/ipykernel_38387/956392404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category'] = df['Category'].astype('category')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[146], line 2
#       1 df['Category'] = df['Category'].astype('category')
# ----> 2 sns.countplot(df['Category'])
#       3 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
# ...

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ### 4) Show all the Movies that were released in year 2000.

# %%
df[df['year'] == 2000.0]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, year, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: year, dtype: int64

# %% [markdown]
# ### 5) Show only the Titles of all TV Shows that were released in India only.

# %%
df2 = df[(df.Country == 'India') & (df.Category == 'TV Show')]
df2['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df.groupby('Director').Show_Id.count().sort_values(ascending=False).head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Name: Show_Id, dtype: int64

# %% [markdown]
# ### 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df[((df.Category == 'Movie') & (df.Type.str.contains('Comedies'))) | (df.Country == 'United Kingdom')]
# Out:
#      Show_Id Category                              Title            Director  \
# 18       s19    Movie                             15-Aug  Swapnaneel Jayakar
# 19       s20    Movie                                '89                 NaN
# 33       s34    Movie                       #realityhigh    Fernando Lebrija
# 34       s35    Movie                              #Roxy     Michael Kennedy
# 36       s37    Movie                            #Selfie      Cristina Jacob
# ...      ...      ...                                ...                 ...
# 7766   s7765    Movie                               Zero          Aanand Rai
# 7771   s7770    Movie           Zindagi Na Milegi Dobara         Zoya Akhtar
# 7774   s7773    Movie  Zipi & Zape y la Isla del Capitan        Oskar Santos
# 7780   s7779    Movie                         Zombieland     Ruben Fleischer
# 7783   s7782    Movie                               Zoom        Peter Hewitt
#
# ...

# %% [markdown]
# ### 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df2 = df[df['Cast'].notna()]
# df2
df2[df2.Cast.str.contains('Tom Cruise')]
# df
# df2
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#         year Release_Date Rating Duration                        Type  \
# 3860  2020.0   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071  2019.0   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# ### 9) What are the different Ratings defined by Netflix ?

# %%
df.Rating.value_counts()
# Out:
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: Rating, dtype: int64

# %% [markdown]
# ### 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
df[(df.Rating == 'TV-14') & (df.Country=='Canada') & (df.Category=='Movie')].count()
# Out:
# Show_Id         11
# Category        11
# Title           11
# Director        11
# Cast             9
# Country         11
# year            11
# Release_Date    11
# Rating          11
# Duration        11
# Type            11
# Description     11
# dtype: int64

# %% [markdown]
# ### 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
df[(df.Rating=='R') & (df.year > 2018)]
# Out:
#      Show_Id Category               Title                       Director  \
# 7         s8    Movie                 187                 Kevin Reynolds
# 14       s15    Movie                3022                     John Suits
# 65       s66    Movie             13 Sins                   Daniel Stamm
# 68       s69    Movie           14 Blades                     Daniel Lee
# 83       s84    Movie  20th Century Women                     Mike Mills
# ...      ...      ...                 ...                            ...
# 7659   s7658    Movie           Woodshock  Kate Mulleavy, Laura Mulleavy
# 7712   s7711    Movie       Yes, God, Yes                    Karen Maine
# 7738   s7737    Movie         Young Adult                  Jason Reitman
# 7776   s7775    Movie              Zodiac                  David Fincher
# 7780   s7779    Movie          Zombieland                Ruben Fleischer
#
#                                                    Cast  \
# ...

# %% [markdown]
# ### 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   year          7777 non-null   float64
#  7   Release_Date  7777 non-null   datetime64[ns]
#  8   Rating        7780 non-null   object
#  9   Duration      7787 non-null   object
#  10  Type          7787 non-null   object
#  11  Description   7787 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(10)
# memory usage: 790.9+ KB

# %%
df[['Minutes','Unit']] = df['Duration'].str.split(' ', expand=True)
df
# Out:
# /tmp/ipykernel_38387/20960329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Minutes','Unit']] = df['Duration'].str.split(' ', expand=True)
# /tmp/ipykernel_38387/20960329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Minutes','Unit']] = df['Duration'].str.split(' ', expand=True)
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# ...

# %%
df[(df.Minutes == df.Minutes.max()) & (df.Unit=='min')]
# Out:
#      Show_Id Category                                        Title  \
# 27       s28    Movie                                       #Alive
# 33       s34    Movie                                 #realityhigh
# 42       s43    Movie                  Çok Filim Hareketler Bunlar
# 121     s122    Movie                               50 First Dates
# 147     s148    Movie      A Babysitter's Guide to Monster Hunting
# ...      ...      ...                                          ...
# 7449   s7448    Movie                                          VS.
# 7527   s7526    Movie                        Welcome Mr. President
# 7559   s7558    Movie                         What Keeps You Alive
# 7638   s7637    Movie  Winter on Fire: Ukraine's Fight for Freedom
# 7784   s7783    Movie                                         Zozo
#
#                Director                                               Cast  \
# 27               Cho Il                           Yoo Ah-in, Park Shin-hye
# ...

# %%
import re
for i in df['Duration']:
    i = int(re.findall(r'\d+', i)[0])
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df['Duration'].value_counts()
# Out:
# 1 Season     1608
# 2 Seasons     382
# 3 Seasons     184
# 90 min        136
# 93 min        131
#              ...
# 182 min         1
# 224 min         1
# 233 min         1
# 196 min         1
# 191 min         1
# Name: Duration, Length: 216, dtype: int64

# %%
df2 = df[~(df.Duration.str.contains('Season'))]
df2
# Out:
#      Show_Id Category                                    Title  \
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
import re
for index, value in enumerate(df2['Duration']):
    df2.at[index, 'Duration'] = int(re.findall(r'\d+', value)[0])
df2
# Out:
# /tmp/ipykernel_38387/3456625317.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.at[index, 'Duration'] = int(re.findall(r'\d+', value)[0])
#      Show_Id Category  Title           Director  \
# 1         s2    Movie  07:19  Jorge Michel Grau
# 2         s3    Movie  23:59       Gilbert Chan
# 3         s4    Movie      9        Shane Acker
# 4         s5    Movie     21     Robert Luketic
# 6         s7    Movie    122    Yasir Al Yasiri
# ...      ...      ...    ...                ...
# 5355     NaN      NaN    NaN                NaN
# 5356     NaN      NaN    NaN                NaN
# 5363     NaN      NaN    NaN                NaN
# 5367     NaN      NaN    NaN                NaN
# 5371     NaN      NaN    NaN                NaN
#
# ...

# %%
df2['Duration'] = df2['Duration'].astype('int')
df2[df2.Duration == df2.Duration.max()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 df2['Duration'] = df2['Duration'].astype('int')
#       2 df2[df2.Duration == df2.Duration.max()]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df2.Duration.str.contains('min')
# Out:
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 6       NaN
#        ...
# 5355    NaN
# 5356    NaN
# 5363    NaN
# 5367    NaN
# 5371    NaN
# Name: Duration, Length: 7009, dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7009 entries, 1 to 5371
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       5377 non-null   object
#  1   Category      5377 non-null   object
#  2   Title         5377 non-null   object
#  3   Director      5214 non-null   object
#  4   Cast          4951 non-null   object
#  5   Country       5147 non-null   object
#  6   year          5377 non-null   float64
#  7   Release_Date  5377 non-null   datetime64[ns]
#  8   Rating        5372 non-null   object
#  9   Duration      7009 non-null   object
#  10  Type          5377 non-null   object
#  11  Description   5377 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(10)
# memory usage: 969.9+ KB

# %% [markdown]
# ### 11) Which individual country has the Highest No. of TV Shows ?

# %%
df2 = df[df.Category == 'TV Show']
df2.groupby('Country').Show_Id.count().sort_values(ascending=False)
# Out:
# Country
# United States                     705
# United Kingdom                    204
# Japan                             157
# South Korea                       147
# India                              71
#                                  ...
# Mexico, Spain                       1
# China, Hong Kong                    1
# Mauritius, South Africa             1
# Malaysia, Singapore, Hong Kong      1
# Uruguay, Germany                    1
# Name: Show_Id, Length: 183, dtype: int64

# %% [markdown]
# ### 12) How can we sort the dataset by Year ?

# %%
df.sort_values('year', ascending=True)
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %% [markdown]
# ### 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df[(df.Category == 'Movie')&(df.Type.str.contains('Dramas')) | ((df.Category == 'TV Show')&(df.Type.str.contains('Kids')))]
# Out:
#      Show_Id Category        Title           Director  \
# 1         s2    Movie        07:19  Jorge Michel Grau
# 4         s5    Movie           21     Robert Luketic
# 7         s8    Movie          187     Kevin Reynolds
# 10       s11    Movie         1922       Zak Hilditch
# 15       s16    Movie       Oct-01     Kunle Afolayan
# ...      ...      ...          ...                ...
# 7778   s7777    Movie     Zokkomon   Satyajit Bhatkal
# 7779   s7778  TV Show  Zombie Dumb                NaN
# 7782   s7781    Movie          Zoo       Shlok Sharma
# 7784   s7783    Movie         Zozo        Josef Fares
# 7785   s7784    Movie       Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# ...
